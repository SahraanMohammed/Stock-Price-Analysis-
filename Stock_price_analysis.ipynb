# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /Users/sahraanmohammed/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
import glob

# %%
glob.glob(r'/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/*csv')
# Out:
# ['/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/XRX_data.csv',
#  '/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/GS_data.csv',
#  '/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/SPGI_data.csv',
#  '/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/MTB_data.csv',
#  '/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/V_data.csv',
#  '/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/CTAS_data.csv',
#  '/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/ESRX_data.csv',
#  '/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/APH_data.csv',
#  '/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/BBT_data.csv',
#  '/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/RHI_data.csv',
# ...

# %%
len(glob.glob(r'/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/*csv'))
# Out:
# 509

# %%
company_list = [
    r'/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/AAPL_data.csv',
    r'/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/AMZN_data.csv',
    r'/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/GOOG_data.csv',
    r'/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/MSFT_data.csv',
]

# %%
all_data = pd.DataFrame()

for file in company_list:
    current_df = pd.read_csv(file)
    all_data = current_df._append(all_data,ignore_index=True)
    ##full_df = pd.concat([full_df, current_df], ignore_index = True

# %%
all_data.shape
# Out:
# (4752, 7)

# %%
all_data
# Out:
#             date     open    high       low   close    volume  Name
# 0     2013-02-08   27.350   27.71   27.3100   27.55  33318306  MSFT
# 1     2013-02-11   27.650   27.92   27.5000   27.86  32247549  MSFT
# 2     2013-02-12   27.880   28.00   27.7500   27.88  35990829  MSFT
# 3     2013-02-13   27.930   28.11   27.8800   28.03  41715530  MSFT
# 4     2013-02-14   27.920   28.06   27.8700   28.04  32663174  MSFT
# ...          ...      ...     ...       ...     ...       ...   ...
# 4747  2018-02-01  167.165  168.62  166.7600  167.78  47230787  AAPL
# 4748  2018-02-02  166.000  166.80  160.1000  160.50  86593825  AAPL
# 4749  2018-02-05  159.100  163.88  156.0000  156.49  72738522  AAPL
# 4750  2018-02-06  154.830  163.72  154.0000  163.03  68243838  AAPL
# 4751  2018-02-07  163.085  163.40  159.0685  159.54  51608580  AAPL
#
# [4752 rows x 7 columns]

# %%
all_data['Name'].unique()
# Out:
# array(['MSFT', 'GOOG', 'AMZN', 'AAPL'], dtype=object)

# %%
all_data.isnull().sum()
# Out:
# date      0
# open      0
# high      0
# low       0
# close     0
# volume    0
# Name      0
# dtype: int64

# %%
all_data.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
all_data
# Out:
#             date     open    high       low   close    volume  Name
# 0     2013-02-08   27.350   27.71   27.3100   27.55  33318306  MSFT
# 1     2013-02-11   27.650   27.92   27.5000   27.86  32247549  MSFT
# 2     2013-02-12   27.880   28.00   27.7500   27.88  35990829  MSFT
# 3     2013-02-13   27.930   28.11   27.8800   28.03  41715530  MSFT
# 4     2013-02-14   27.920   28.06   27.8700   28.04  32663174  MSFT
# ...          ...      ...     ...       ...     ...       ...   ...
# 4747  2018-02-01  167.165  168.62  166.7600  167.78  47230787  AAPL
# 4748  2018-02-02  166.000  166.80  160.1000  160.50  86593825  AAPL
# 4749  2018-02-05  159.100  163.88  156.0000  156.49  72738522  AAPL
# 4750  2018-02-06  154.830  163.72  154.0000  163.03  68243838  AAPL
# 4751  2018-02-07  163.085  163.40  159.0685  159.54  51608580  AAPL
#
# [4752 rows x 7 columns]

# %%
all_data['date'] = pd.to_datetime(all_data['date'])

# %%
all_data['date']
# Out:
# 0      2013-02-08
# 1      2013-02-11
# 2      2013-02-12
# 3      2013-02-13
# 4      2013-02-14
#           ...
# 4747   2018-02-01
# 4748   2018-02-02
# 4749   2018-02-05
# 4750   2018-02-06
# 4751   2018-02-07
# Name: date, Length: 4752, dtype: datetime64[ns]

# %%
all_data.dtypes
# Out:
# date      datetime64[ns]
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# Name              object
# dtype: object

# %%
tech_list = all_data['Name'].unique()

# %%
tech_list
# Out:
# array(['MSFT', 'GOOG', 'AMZN', 'AAPL'], dtype=object)

# %%
plt.figure(figsize=(20,12))
for index, company in enumerate(tech_list,1):
    plt.subplot(2,2,index)
    filter1 = all_data['Name']==company
    df = all_data[filter1]
    plt.plot(df['date'], df['close'])
    plt.title(company)

# %%
all_data['close'].rolling(window=10).mean().head(14)
# Out:
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN
# 7         NaN
# 8         NaN
# 9     27.8535
# 10    27.8355
# 11    27.7865
# 12    27.7795
# 13    27.7565
# Name: close, dtype: float64

# %%
new_data = all_data.copy()

# %%
ma_day = [10, 20, 50]

for ma in ma_day:
    new_data['close_' + str(ma)] = new_data['close'].rolling(ma).mean()

# %%
new_data.tail(7)
# Out:
#            date     open      high       low   close    volume  Name  \
# 4745 2018-01-30  165.525  167.3700  164.7000  166.97  46048185  AAPL
# 4746 2018-01-31  166.870  168.4417  166.5000  167.43  32478930  AAPL
# 4747 2018-02-01  167.165  168.6200  166.7600  167.78  47230787  AAPL
# 4748 2018-02-02  166.000  166.8000  160.1000  160.50  86593825  AAPL
# 4749 2018-02-05  159.100  163.8800  156.0000  156.49  72738522  AAPL
# 4750 2018-02-06  154.830  163.7200  154.0000  163.03  68243838  AAPL
# 4751 2018-02-07  163.085  163.4000  159.0685  159.54  51608580  AAPL
#
#       close_10  close_20  close_50
# 4745   174.263  174.3340  172.9460
# 4746   173.096  174.0925  172.8726
# 4747   171.948  173.8700  172.8252
# 4748   170.152  173.2435  172.6356
# 4749   168.101  172.3180  172.3026
# 4750   166.700  171.7520  172.0640
# 4751   165.232  171.0125  171.7554

# %%
new_data.set_index('date', inplace=True)

# %%
new_data
# Out:
#                open    high       low   close    volume  Name  close_10  \
# date
# 2013-02-08   27.350   27.71   27.3100   27.55  33318306  MSFT       NaN
# 2013-02-11   27.650   27.92   27.5000   27.86  32247549  MSFT       NaN
# 2013-02-12   27.880   28.00   27.7500   27.88  35990829  MSFT       NaN
# 2013-02-13   27.930   28.11   27.8800   28.03  41715530  MSFT       NaN
# 2013-02-14   27.920   28.06   27.8700   28.04  32663174  MSFT       NaN
# ...             ...     ...       ...     ...       ...   ...       ...
# 2018-02-01  167.165  168.62  166.7600  167.78  47230787  AAPL   171.948
# 2018-02-02  166.000  166.80  160.1000  160.50  86593825  AAPL   170.152
# 2018-02-05  159.100  163.88  156.0000  156.49  72738522  AAPL   168.101
# 2018-02-06  154.830  163.72  154.0000  163.03  68243838  AAPL   166.700
# 2018-02-07  163.085  163.40  159.0685  159.54  51608580  AAPL   165.232
#
#             close_20  close_50
# date
# 2013-02-08       NaN       NaN
# ...

# %%
new_data.columns
# Out:
# Index(['open', 'high', 'low', 'close', 'volume', 'Name', 'close_10',
#        'close_20', 'close_50'],
#       dtype='object')

# %%
plt.figure(figsize=(20,12))
for index, company in enumerate(tech_list,1):
    plt.subplot(2,2,index)
    filter1 = new_data['Name']==company
    df = new_data[filter1]
    df[['close_10','close_20', 'close_50']].plot(ax=plt.gca())
    plt.title(company)

# %%
company_list
# Out:
# ['/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/AAPL_data.csv',
#  '/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/AMZN_data.csv',
#  '/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/GOOG_data.csv',
#  '/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/MSFT_data.csv']

# %%
apple = pd.read_csv(r'/Users/sahraanmohammed/Documents/Python BI Analyst/individual_stocks_5yr/AAPL_data.csv')

# %%
apple.head(4)
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL

# %%
apple['close']
# Out:
# 0        67.8542
# 1        68.5614
# 2        66.8428
# 3        66.7156
# 4        66.6556
#           ...
# 1254    167.7800
# 1255    160.5000
# 1256    156.4900
# 1257    163.0300
# 1258    159.5400
# Name: close, Length: 1259, dtype: float64

# %%
apple['Daily return(in %)'] = apple['close'].pct_change() * 100

# %%
apple.head(4)
# Out:
#          date     open     high      low    close     volume  Name  \
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
#
#    Daily return(in %)
# 0                 NaN
# 1            1.042235
# 2           -2.506658
# 3           -0.190297

# %%
import plotly.offline as py
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
py.init_notebook_mode(connected=True)
import plotly.graph_objs as go
import plotly.io as pio
pio.renderers.default = 'colab'
from plotly.offline import init_notebook_mode, iplot
import plotly.io as pio
pio.renderers.default = 'colab'
from plotly.offline import init_notebook_mode, iplot
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
px.line(apple, x='date', y='Daily return(in %)')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 px.line(apple, x='date', y='Daily return(in %)')
#
# NameError: name 'px' is not defined

# %%
apple.dtypes

# %%
apple['date'] = pd.to_datetime(apple['date'])

# %%
apple.dtypes

# %%
apple.head(4)

# %%
apple.set_index('date',inplace=True)

# %%
apple.head(4)

# %%
apple['close'].resample('ME').mean()

# %%
apple['close'].resample('ME').mean().plot()

# %%
apple['close'].resample('YE').mean().plot()

# %%
apple['close'].resample('QE').mean().plot()

# %%
company_list

# %%
company_list[0]

# %%
app = pd.read_csv(company_list[0])
amzn = pd.read_csv(company_list[1])
google = pd.read_csv(company_list[2])
msft = pd.read_csv(company_list[3])

# %%
closing_price=pd.DataFrame()

# %%
closing_price['apple_close'] = app['close']
closing_price['amzn_close '] = amzn['close']
closing_price['google_close '] = google['close']
closing_price['msft_close'] = msft['close']

# %%
closing_price

# %%
sns.pairplot(closing_price)

# %%
closing_price.corr()

# %%
sns.heatmap(closing_price.corr(), annot = True)

# %%
closing_pctchange=pd.DataFrame()

# %%
closing_pctchange['apple_close_pct_change'] = app['close'].pct_change()*100
closing_pctchange['amzn_close_pct_change'] = amzn['close'].pct_change()*100
closing_pctchange['google_close_pct_change'] = google['close'].pct_change()*100
closing_pctchange['msft_close_pct_change'] = msft['close'].pct_change()*100

# %%
closing_pctchange

# %%
g = sns.PairGrid(data = closing_pctchange)
g.map_diag(sns.histplot)
g.map_lower(sns.scatterplot)
g.map_upper(sns.kdeplot)

# %%
closing_pctchange.corr()
